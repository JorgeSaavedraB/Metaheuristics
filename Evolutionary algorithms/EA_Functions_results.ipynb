# %%
from EA_FunctionsEvaluation import evaluations
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Generational models (size offspring = popsize)

# %% [markdown]
# ## D=10

# %%
D = 10 # Dimension 
popsize = 30
size_offspring = popsize
num_generations = D * 100
num_evaluations = D * 100
n_arrows = int(D - D / 4) # Solo para EA1 y EA2
mutation_rate = 0.1

# %%
results_EA1_G_10 = evaluations(EA='EA1', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA1_G_10.npy', results_EA1_G_10)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  113462430917.38055
# Evaluación final (mejor de la población):  51367172937.02428
# Tiempo de evaluación:  0.1125
# Función:  1
# Evaluación inicial (mejor de la población):  81067.50142057071
# Evaluación final (mejor de la población):  26091.735222738702
# Tiempo de evaluación:  0.1478
# Función:  2
# Evaluación inicial (mejor de la población):  933.2992262820195
# Evaluación final (mejor de la población):  463.20812253610825
# Tiempo de evaluación:  0.1217
# Función:  3
# Evaluación inicial (mejor de la población):  139.4891382606869
# Evaluación final (mejor de la población):  50.91917309999203
# Tiempo de evaluación:  0.124
# Función:  4
# Evaluación inicial (mejor de la población):  4.136594732025411
# Evaluación final (mejor de la población):  2.8361794280067705
# Tiempo de evaluación:  0.1271
# Función:  5
# Evaluación inicial (mejor de la población):  498.2459021412667
# ...

# %%
results_EA2_G_10 = evaluations(EA='EA2', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA2_G_10.npy', results_EA2_G_10)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  126711777344.00737
# Evaluación final (mejor de la población):  15034418500.293087
# Tiempo de evaluación:  0.0687
# Función:  1
# Evaluación inicial (mejor de la población):  66696.59949825096
# Evaluación final (mejor de la población):  21245.243436967346
# Tiempo de evaluación:  0.0908
# Función:  2
# Evaluación inicial (mejor de la población):  3969.9337051601515
# Evaluación final (mejor de la población):  683.1521288937051
# Tiempo de evaluación:  0.09
# Función:  3
# Evaluación inicial (mejor de la población):  120.63288727886302
# Evaluación final (mejor de la población):  46.550319709721656
# Tiempo de evaluación:  0.0704
# Función:  4
# Evaluación inicial (mejor de la población):  4.168502652204107
# Evaluación final (mejor de la población):  3.078694672964919
# Tiempo de evaluación:  0.0805
# Función:  5
# Evaluación inicial (mejor de la población):  590.2675462347485
# ...

# %%
results_EA3_G_10 = evaluations(EA='EA3', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA3_G_10.npy', results_EA3_G_10)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  113179210582.87575
# Evaluación final (mejor de la población):  10657635841.2817
# Tiempo de evaluación:  0.2392
# Función:  1
# Evaluación inicial (mejor de la población):  220637.93152746564
# Evaluación final (mejor de la población):  21815.974046541873
# Tiempo de evaluación:  0.2442
# Función:  2
# Evaluación inicial (mejor de la población):  758.3085025790531
# Evaluación final (mejor de la población):  34.991934922780494
# Tiempo de evaluación:  0.2186
# Función:  3
# Evaluación inicial (mejor de la población):  136.82823514954782
# Evaluación final (mejor de la población):  9.761186936848514
# Tiempo de evaluación:  0.2214
# Función:  4
# Evaluación inicial (mejor de la población):  4.10426741966123
# Evaluación final (mejor de la población):  2.629955138890218
# Tiempo de evaluación:  0.2435
# Función:  5
# Evaluación inicial (mejor de la población):  493.16564465042154
# ...

# %% [markdown]
# ## D=30

# %%
D = 30 # Dimension 
popsize = 30
size_offspring = popsize
num_generations = D * 100
num_evaluations = D * 100
n_arrows = int(D - D / 4) # Solo para EA1 y EA2
mutation_rate = 0.1

# %%
results_EA1_G_30 = evaluations(EA='EA1', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA1_G_30.npy', results_EA1_G_30)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  664343232755.3723
# Evaluación final (mejor de la población):  165371529962.73184
# Tiempo de evaluación:  0.5511
# Función:  1
# Evaluación inicial (mejor de la población):  140806344.9129513
# Evaluación final (mejor de la población):  118597.926748141
# Tiempo de evaluación:  0.6321
# Función:  2
# Evaluación inicial (mejor de la población):  13941.366315114501
# Evaluación final (mejor de la población):  1795.3950671775547
# Tiempo de evaluación:  0.6296
# Función:  3
# Evaluación inicial (mejor de la población):  439.5385052911335
# Evaluación final (mejor de la población):  140.2650080904875
# Tiempo de evaluación:  0.6592
# Función:  4
# Evaluación inicial (mejor de la población):  13.293753054432646
# Evaluación final (mejor de la población):  11.775810613306126
# Tiempo de evaluación:  0.5814
# Función:  5
# Evaluación inicial (mejor de la población):  2426.366890628864
# ...

# %%
results_EA2_G_30 = evaluations(EA='EA2', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA2_G_30.npy', results_EA2_G_30)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  574586397379.1816
# Evaluación final (mejor de la población):  192746193100.0754
# Tiempo de evaluación:  0.3323
# Función:  1
# Evaluación inicial (mejor de la población):  19052588.672284454
# Evaluación final (mejor de la población):  69472.68017423793
# Tiempo de evaluación:  0.3659
# Función:  2
# Evaluación inicial (mejor de la población):  15217.481815996494
# Evaluación final (mejor de la población):  2107.490762677154
# Tiempo de evaluación:  0.345
# Función:  3
# Evaluación inicial (mejor de la población):  462.2247362383047
# Evaluación final (mejor de la población):  202.20458820717477
# Tiempo de evaluación:  0.3336
# Función:  4
# Evaluación inicial (mejor de la población):  13.7622584373947
# Evaluación final (mejor de la población):  11.309425759565313
# Tiempo de evaluación:  0.388
# Función:  5
# Evaluación inicial (mejor de la población):  2587.944058198797
# ...

# %%
results_EA3_G_30 = evaluations(EA='EA3', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA3_G_30.npy', results_EA3_G_30)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  663398856390.3474
# Evaluación final (mejor de la población):  37240064533.50629
# Tiempo de evaluación:  0.8771
# Función:  1
# Evaluación inicial (mejor de la población):  96616499.06808864
# Evaluación final (mejor de la población):  74284.2131741124
# Tiempo de evaluación:  0.9847
# Función:  2
# Evaluación inicial (mejor de la población):  13507.189542234164
# Evaluación final (mejor de la población):  568.8851860750897
# Tiempo de evaluación:  0.9844
# Función:  3
# Evaluación inicial (mejor de la población):  467.73126975522155
# Evaluación final (mejor de la población):  59.62205941434355
# Tiempo de evaluación:  0.9087
# Función:  4
# Evaluación inicial (mejor de la población):  13.76634561580859
# Evaluación final (mejor de la población):  9.688495566084535
# Tiempo de evaluación:  0.9606
# Función:  5
# Evaluación inicial (mejor de la población):  3143.5257293044288
# ...

# %% [markdown]
# # Steady-State models (size offspring < popsize)

# %% [markdown]
# ## D=10

# %%
D = 10 # Dimension 
popsize = 30
size_offspring = int(popsize/2)
num_generations = D * 100
num_evaluations = D * 100
n_arrows = int(D - D / 4) # Solo para EA1 y EA2
mutation_rate = 0.1

# %%
results_EA1_SS_10 = evaluations(EA='EA1', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA1_SS_10.npy', results_EA1_SS_10)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  141097408546.72464
# Evaluación final (mejor de la población):  117651054264.15817
# Tiempo de evaluación:  0.1616
# Función:  1
# Evaluación inicial (mejor de la población):  32998104.294210788
# Evaluación final (mejor de la población):  58131.05119182397
# Tiempo de evaluación:  0.1976
# Función:  2
# Evaluación inicial (mejor de la población):  3957.3924873039023
# Evaluación final (mejor de la población):  511.52079645871186
# Tiempo de evaluación:  0.1744
# Función:  3
# Evaluación inicial (mejor de la población):  135.02227828589037
# Evaluación final (mejor de la población):  125.88275027060038
# Tiempo de evaluación:  0.1795
# Función:  4
# Evaluación inicial (mejor de la población):  3.9496024450789307
# Evaluación final (mejor de la población):  3.454397285413537
# Tiempo de evaluación:  0.2278
# Función:  5
# Evaluación inicial (mejor de la población):  456.83015917105007
# ...

# %%
results_EA2_SS_10 = evaluations(EA='EA2', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA2_SS_10.npy', results_EA2_SS_10)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  172730253184.94174
# Evaluación final (mejor de la población):  11353745228.001862
# Tiempo de evaluación:  0.2024
# Función:  1
# Evaluación inicial (mejor de la población):  4082076.69472896
# Evaluación final (mejor de la población):  17550.216777118578
# Tiempo de evaluación:  0.8387
# Función:  2
# Evaluación inicial (mejor de la población):  2516.1705642211055
# Evaluación final (mejor de la población):  164.70660284018103
# Tiempo de evaluación:  0.2207
# Función:  3
# Evaluación inicial (mejor de la población):  126.13926280286577
# Evaluación final (mejor de la población):  43.581158948572494
# Tiempo de evaluación:  0.1494
# Función:  4
# Evaluación inicial (mejor de la población):  4.093196925618912
# Evaluación final (mejor de la población):  3.1978085185090115
# Tiempo de evaluación:  0.4882
# Función:  5
# Evaluación inicial (mejor de la población):  532.3736223901318
# ...

# %%
results_EA3_SS_10 = evaluations(EA='EA3', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA3_SS_10.npy', results_EA3_SS_10)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  179727801362.38715
# Evaluación final (mejor de la población):  10240518903.088331
# Tiempo de evaluación:  0.2011
# Función:  1
# Evaluación inicial (mejor de la población):  218866.373498976
# Evaluación final (mejor de la población):  6806.3029422803165
# Tiempo de evaluación:  0.2037
# Función:  2
# Evaluación inicial (mejor de la población):  2733.2802050315277
# Evaluación final (mejor de la población):  109.59192130488677
# Tiempo de evaluación:  0.2947
# Función:  3
# Evaluación inicial (mejor de la población):  140.03664928963144
# Evaluación final (mejor de la población):  34.79697507759382
# Tiempo de evaluación:  0.2101
# Función:  4
# Evaluación inicial (mejor de la población):  4.112173091289307
# Evaluación final (mejor de la población):  2.314851540720709
# Tiempo de evaluación:  0.218
# Función:  5
# Evaluación inicial (mejor de la población):  284.1301448266929
# ...

# %% [markdown]
# ## D=30

# %%
D = 30 # Dimension 
popsize = 30
size_offspring = int(popsize/2)
num_generations = D * 100
num_evaluations = D * 100
n_arrows = int(D - D / 4) # Solo para EA1 y EA2
mutation_rate = 0.1

# %%
results_EA1_SS_30 = evaluations(EA='EA1', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA1_SS_30.npy', results_EA1_SS_30)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  547867721659.5212
# Evaluación final (mejor de la población):  486113508907.0027
# Tiempo de evaluación:  0.878
# Función:  1
# Evaluación inicial (mejor de la población):  2015815304.4934065
# Evaluación final (mejor de la población):  2452484.201495153
# Tiempo de evaluación:  1.5923
# Función:  2
# Evaluación inicial (mejor de la población):  14456.325942972806
# Evaluación final (mejor de la población):  10086.437684292123
# Tiempo de evaluación:  0.8071
# Función:  3
# Evaluación inicial (mejor de la población):  464.9888043399761
# Evaluación final (mejor de la población):  454.56549919221277
# Tiempo de evaluación:  0.7794
# Función:  4
# Evaluación inicial (mejor de la población):  13.853984678394406
# Evaluación final (mejor de la población):  13.763551882578884
# Tiempo de evaluación:  0.9868
# Función:  5
# Evaluación inicial (mejor de la población):  2750.029417537339
# ...

# %%
results_EA2_SS_30 = evaluations(EA='EA2', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA2_SS_30.npy', results_EA2_SS_30)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  689221739398.8478
# Evaluación final (mejor de la población):  300294964828.72424
# Tiempo de evaluación:  0.4403
# Función:  1
# Evaluación inicial (mejor de la población):  803025.7591177016
# Evaluación final (mejor de la población):  65661.0834870392
# Tiempo de evaluación:  0.5088
# Función:  2
# Evaluación inicial (mejor de la población):  17342.943829282885
# Evaluación final (mejor de la población):  1626.9277383003107
# Tiempo de evaluación:  0.4964
# Función:  3
# Evaluación inicial (mejor de la población):  468.04140609529804
# Evaluación final (mejor de la población):  137.88286741320906
# Tiempo de evaluación:  0.4867
# Función:  4
# Evaluación inicial (mejor de la población):  13.763251497945644
# Evaluación final (mejor de la población):  11.879548568727001
# Tiempo de evaluación:  0.4773
# Función:  5
# Evaluación inicial (mejor de la población):  2391.3082335071103
# ...

# %%
results_EA3_SS_30 = evaluations(EA='EA3', 
                dimension=D, 
                popsize=popsize, 
                size_offspring=size_offspring,
                num_generations=num_generations, 
                num_evaluations=num_evaluations,
                n_arrows=n_arrows,
                mutation_rate=mutation_rate)
np.save('EA3_SS_30.npy', results_EA3_SS_30)
# Out:
# Ejecución:  0
# Función:  0
# Evaluación inicial (mejor de la población):  664415369181.9065
# Evaluación final (mejor de la población):  62711639602.709
# Tiempo de evaluación:  0.731
# Función:  1
# Evaluación inicial (mejor de la población):  166045103.83669543
# Evaluación final (mejor de la población):  71562.7014326203
# Tiempo de evaluación:  0.8569
# Función:  2
# Evaluación inicial (mejor de la población):  20604.311436485274
# Evaluación final (mejor de la población):  581.3081264294284
# Tiempo de evaluación:  0.7114
# Función:  3
# Evaluación inicial (mejor de la población):  433.91130717573196
# Evaluación final (mejor de la población):  54.11346616988854
# Tiempo de evaluación:  0.8173
# Función:  4
# Evaluación inicial (mejor de la población):  14.076975678526873
# Evaluación final (mejor de la población):  11.446558972612825
# Tiempo de evaluación:  0.7637
# Función:  5
# Evaluación inicial (mejor de la población):  2980.8397240699387
# ...
